# %%
import pandas as pd
import numpy as np
import csv

# %%
data = csv.reader('dataset1.csv', delimiter='|')
data2 = data[['person_id', 'sex_cd', 'birth' 'zbs_cd']].groupby(['sexo','birth','zbs_cd']).agg('count')
data2
